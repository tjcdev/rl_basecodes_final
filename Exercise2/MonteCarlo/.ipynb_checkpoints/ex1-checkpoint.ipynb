# %%
actions = ["DRIBBLE_UP","DRIBBLE_DOWN","DRIBBLE_LEFT","DRIBBLE_RIGHT","SHOOT"]
state_values = dict((((i, j), a), 0) 
                         for i in range(5) 
                             for j in range(5)
                                for a in actions)

# %%
state_values
# Out:
# {((0, 0), 'DRIBBLE_UP'): 0,
#  ((0, 0), 'DRIBBLE_DOWN'): 0,
#  ((0, 0), 'DRIBBLE_LEFT'): 0,
#  ((0, 0), 'DRIBBLE_RIGHT'): 0,
#  ((0, 0), 'SHOOT'): 0,
#  ((0, 1), 'DRIBBLE_UP'): 0,
#  ((0, 1), 'DRIBBLE_DOWN'): 0,
#  ((0, 1), 'DRIBBLE_LEFT'): 0,
#  ((0, 1), 'DRIBBLE_RIGHT'): 0,
#  ((0, 1), 'SHOOT'): 0,
#  ((0, 2), 'DRIBBLE_UP'): 0,
#  ((0, 2), 'DRIBBLE_DOWN'): 0,
#  ((0, 2), 'DRIBBLE_LEFT'): 0,
#  ((0, 2), 'DRIBBLE_RIGHT'): 0,
#  ((0, 2), 'SHOOT'): 0,
#  ((0, 3), 'DRIBBLE_UP'): 0,
#  ((0, 3), 'DRIBBLE_DOWN'): 0,
#  ((0, 3), 'DRIBBLE_LEFT'): 0,
#  ((0, 3), 'DRIBBLE_RIGHT'): 0,
#  ((0, 3), 'SHOOT'): 0,
#  ((0, 4), 'DRIBBLE_UP'): 0,
#  ((0, 4), 'DRIBBLE_DOWN'): 0,
#  ((0, 4), 'DRIBBLE_LEFT'): 0,
#  ((0, 4), 'DRIBBLE_RIGHT'): 0,
#  ((0, 4), 'SHOOT'): 0,
#  ((1, 0), 'DRIBBLE_UP'): 0,
#  ((1, 0), 'DRIBBLE_DOWN'): 0,
#  ((1, 0), 'DRIBBLE_LEFT'): 0,
#  ((1, 0), 'DRIBBLE_RIGHT'): 0,
#  ((1, 0), 'SHOOT'): 0,
#  ((1, 1), 'DRIBBLE_UP'): 0,
#  ((1, 1), 'DRIBBLE_DOWN'): 0,
# ...
